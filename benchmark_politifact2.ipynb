# %% [markdown]
# # Benchmarking Politifact 2 Suite

# %%
from langchain_community.llms import Ollama
from factCheck import factCheckSingleClaim, factCheckSingleClaimNoContext

OLLAMA_HOST = "http://host.docker.internal:11434" # for when running within docker image
# OLLAMA_HOST = "http://localhost:11434"
 
ollama3 = Ollama(model="llama3", base_url=OLLAMA_HOST)
ollama32 = Ollama(model="llama3.2", base_url=OLLAMA_HOST)

claimCount = 100
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
from sklearn.metrics import accuracy_score, f1_score

# Evaluation function
def evaluate_model(predictions, y):
    for idx in range(len(predictions)):
        if y[idx] in predictions[idx]:
            predictions[idx] = y[idx];
        else:
            predictions[idx] = predictions[idx][0];
    
    # Ensure predictions and dataset labels are aligned
    accuracy = accuracy_score(y, predictions)
    f1 = f1_score(y, predictions, average='weighted')
    return accuracy, f1

# %%
from benchmarking.politifact.politifactEval import get_politifact_sample

dfPol = get_politifact_sample(claimCount, './benchmarking/politifact/politifact_factcheck_data.json', 42)

# %%
import time
from datetime import datetime
start_time = time.time()

polMapping = {
    "true": ["true"],
    "mostly true": ["mostly true", "half-true"],
    "mostly false": ["mostly false", "half-true"],
    "false": ["false", "pants-fire"],
    "not enough evidence": ["Not Enough Evidence"]
}

modelResults = [{'name': 'FactCheck3'}, {'name': 'FactCheck32'}]
for modelIndex, model in enumerate([ollama3, ollama32]):
    # FactCheckLLM check
    origPred = []
    polPred = []
    responses = []
    for row in dfPol.iterrows(): 
        pred = await factCheckSingleClaim(row[1]['statement'], model, True)
        origPred.append(pred['label'].lower())
        pred['label'] = polMapping[pred['label'].lower()]
        polPred.append(pred['label'])
        responses.append(pred['reply'])
        
    modelResults[modelIndex]['dataset'] = 'POLITIFACT';
    modelResults[modelIndex]['original-prediction'] = origPred;
    modelResults[modelIndex]['mapped-predictions'] = polPred;
    modelResults[modelIndex]['res'] = responses;
    
    acc, f1 = evaluate_model(polPred, dfPol['verdict'].values)
    modelResults[modelIndex]['acc'] = acc
    modelResults[modelIndex]['f1'] = f1

end_time = time.time()
elapsed_time = end_time - start_time
minutes, seconds = divmod(elapsed_time, 60)
print(f"{int(minutes)} minutes and {seconds:.2f} seconds")
# Out:
# CLAIM: Jeb Bush: "Barack Obama will somehow manage to add more than $8 trillion to the national debt, which is more debt than the 43 presidents who held office before him compiled together."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Donald Trump: Says President Obama's "grandmother in Kenya said he was born in Kenya and she was there and witnessed the birth."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Bloggers: The COVID-19 vaccines "suppress the immune system" and make people more susceptible to HIV, shingles and herpes.
# FactCheck Articles: []
# News Articles: []
# CLAIM: Paul Krugman: Says "there have been some job gains in the McMansion State since Mr. Christie took office, but they have lagged gains both in the nation as a whole and in New York and Connecticut, the obvious points of comparison."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Donald Trump: "The FBI said (former national security adviser Michael Flynn) wasn't lying."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Barack Obama: Says Romney would add "trillions" to the deficit while Obama would "cut the deficit by $4 trillion."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Edwin Pacheco: Says Christopher Little has "a history of working against environmental protection by defending the worst types of corporate polluters"
# FactCheck Articles: []
# News Articles: []
# CLAIM: Donald Trump: President Barack Obama "wants to take in 250,000 (people) from Syria."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Facebook posts: Says Gov. Tony Evers "removed the American flag from the Capitol building"
# FactCheck Articles: []
# News Articles: []
# CLAIM: Brandon Morse: Says a video proves Pelosi "was planning" to rip up President Donald Trump’s State of the Union address "from the start."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Viral image: Unvaccinated people "are making the vaccinated people sick and die, but the unvaccinated people are not dead or sick."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Facebook posts: "Rand Paul’s medical license was just revoked!"
# FactCheck Articles: []
# News Articles: []
# CLAIM: Leah Vukmir: Says "I have been through the gauntlet, when we had riots in that Capitol."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Louie Gohmert: Says a Justice Department memo "directs that you must openly embrace gay marriage and homosexuality."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Facebook posts: Colorado "requires photo ID to vote in person, requires signature verification for mail-in ballots, which Georgia got rid of, and prevents campaign workers from giving food, water to voters within 100 feet if they’re wearing campaign apparel."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Charlie Crist: If Florida had not taken the stimulus, it "would have led to the firing of 20,000 teachers."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Bill O'Reilly: Says Supreme Court nominee Merrick Garland "voted, so the folks know, in Washington, D.C., to keep guns away from private citizens."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Brian Treece: Columbia, Mo., is "one of the fastest growing cities in the region, the only city in the state to grow jobs faster than the nation as a whole."
# FactCheck Articles: []
# News Articles: []
# CLAIM: AsAmericanAsApplePie.org: "San Juan city council votes unanimously to impeach Trump-hating mayor."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Justin Nelson: Says "our indicted Attorney General Ken Paxton is back to being the only statewide official in the country under indictment."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Crossroads GPS: "Unions don’t have to comply with Obamacare."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Arianna Huffington: Says although the unemployment rate seems to be improving, it does not reflect real job creation -- it’s caused by a "shrinking of the actual labor force."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Travis Allen: "Homelessness has skyrocketed across California. We have the nation’s highest homelessness rate and the nation’s highest homeless population."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Jim Steineke: The streetcar project planned by Mayor Tom Barrett would be a "1900s style trolley."
# FactCheck Articles: []
# News Articles: []
# CLAIM: David Pepper: "Many states without collective bargaining, such as Arizona, Nevada and North Carolina, have far larger budget deficits than many that do, including Ohio."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Marco Rubio: After Hurricane Hermine in 2016, Tallahassee "didn’t have power for weeks because (Mayor Andrew Gillum) stood in the way of crews being able to come in and restore power, because they weren’t members of the right union or something."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Tweets: "Books banned in Texas include 1984, Maus, and The Handmaid's Tale, but not Mein Kampf."
# FactCheck Articles: []
# News Articles: []
# CLAIM: John Boccieri: "Mr. Renacci was registered as a foreign trade lobbyist in the United States government."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Democratic Party of Wisconsin: Says Donald Trump used farmers’ struggles "to push through a multi-billion dollar bailout program that was nothing more than a handout for large agricultural companies."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Corey Lewandowski: "The chairman of the party of Florida, who is an avid and outward supporter of Marco Rubio, gets to appoint 30 of those delegates."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Bruce Rauner: Says "massive floods" led to Legionnaires’ disease outbreaks at the Quincy Veterans’ Home.
# FactCheck Articles: []
# News Articles: []
# CLAIM: Bernie Sanders: "When you're white ... you don't know what it's like to be poor."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Maria Shriver: "Two-thirds of American families rely on the mother's income to stay above the poverty level."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Facebook posts: "Trump is in White House! He promises to lock up Hillary!"
# FactCheck Articles: []
# News Articles: []
# CLAIM: Roberto DaSilva: "Ten percent of violent deaths in the U.S. each year are due to strangulation."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Joni Ernst: The Obama administration issued an "11th-hour rule that entrenches federal family planning funding for Planned Parenthood."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Facebook posts: Says Nancy Pelosi said, "Waiting long hours in the emergency room will allow you to make new friends!"
# FactCheck Articles: []
# News Articles: []
# CLAIM: Pete Buttigieg: Says President Donald Trump has been "taking money Congress authorized to protect people facing disaster in order to indefinitely detain asylum seekers."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Facebook posts: Says Marco Rubio said that "felons should not have their voting rights restored" but that "convicted felons should be allowed to own guns after they have done their time."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Josh Hawley: Says activists threatened his family and "screamed threats, vandalized, and tried to pound open our door."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Facebook posts: Photos show "Ukrainian Christians pray outdoors, in the snow, for their country in this phase of war danger."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Bill O'Reilly: Tells President Barack Obama that he also asked former President George W. Bush about how he felt about Americans hating him.
# FactCheck Articles: []
# News Articles: []
# CLAIM: Karl Rove: Under a public health care option, 120 million Americans will "lose what they now get from private companies and be forced onto the government-run rolls as businesses decide it is more cost-effective for them to drop coverage."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Facebook posts: Says a video shows Iranian rockets being launched toward a U.S. air base in Iraq.
# FactCheck Articles: []
# News Articles: []
# CLAIM: Michelle Nunn: Says by rejecting an expansion of Medicaid under the new law, Georgia was depriving 25,000 veterans of health care coverage.
# FactCheck Articles: []
# News Articles: []
# CLAIM: Duriya Farooqui: "Of the 18 stadiums built from 2004 to 2013, 47 percent of the total cost came from public sources."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Marco Rubio: "In about three weeks over a half million Floridians are going to lose their coverage again" through Obamacare.
# FactCheck Articles: []
# News Articles: []
# CLAIM: City of Austin: "Nearly 20% of our residents" are born abroad.
# FactCheck Articles: []
# News Articles: []
# CLAIM: Hillary Clinton: "We are seeing kids who are healthier."
# FactCheck Articles: []
# News Articles: []
# CLAIM: West Virginia Democratic Party: The Affordable Care Act "provided over 200,000 West Virginians with health care coverage."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Viral image: "2,000 illegal aliens were arrested by ICE in 2017 for murders committed here in the United States!"
# FactCheck Articles: []
# News Articles: []
# CLAIM: Tom Daschle: U.S. global AIDS spending helped reduce "political instability and violence" by "40 percent" in recipient nations.
# FactCheck Articles: []
# News Articles: []
# CLAIM: Club for Growth: Audio clips from ad show Pat McCrory supported Black Lives Matter protesters while condemning ‘Trump supporters’
# FactCheck Articles: []
# News Articles: []
# CLAIM: Lon Burnam: "Russia has more diversity in its governmental representation than we do in Texas."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Rodney Davis: House Speaker Nancy Pelosi’s "office was calling the shots on all of their (Capitol security officials’) actions on Jan. 6."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Sharlene Leurig: "Austin is the only city in an arid landscape in the western United States dependent on a single source of water."
# FactCheck Articles: []
# News Articles: []
# CLAIM: John McCain: "Obama himself voted against funding our nation's veterans and troops in the field during a time of war."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Steven Goldstein: "Polls now show a majority of Catholics favor marriage equality."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Chain email: "The President wants the U.S. to sign on to the U.N.’s International Criminal Court."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Facebook posts: Says Donald Trump wrote in his book, "Being an atheist gives me an edge in every deal. Christians are too moral for business."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Donald Trump: "In the first full month of my administration following the issuance of my executive orders, illegal immigration on our southern border fell by an unprecedented 40 percent."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Charlie Crist: Says property insurance rates are going up because Rick Scott signed a bill preventing the state from regulating insurance.
# FactCheck Articles: []
# News Articles: []
# CLAIM: Donald Trump: "Our new (health care) plans are up to 60% less expensive and better" than Obamacare.
# FactCheck Articles: []
# News Articles: []
# CLAIM: John McCain: Earmarks requested in a federal spending bill included  "$277,000 for potato pest management in Wisconsin."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Ted Wheeler: Says the treasurer’s office has "saved $37 million in management costs for the oversight of public investments."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Bloggers: "NBC just fired Megyn Kelly before her new show begins."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Conservative Tribune: "Before Leaving, Obama Enacts Rules to Take $3,000 From EVERY American."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Charlie Crist: Marco Rubio "wants to raise the Social Security retirement age," and "cut benefits."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Donald Trump: Speaking of his restriction on travel from China, "I had (Joe) Biden calling me xenophobic. … He called me a racist, because of the fact that he felt it was a racist thing to stop people from China coming in."
# FactCheck Articles: []
# News Articles: []
# CLAIM: American Postal Workers Union: "The U.S. Postal Service doesn’t run on your tax dollars. It’s funded solely by stamps and postage."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Tim Scott: "If you don't pay income taxes ... you'll have more money" under the Republican tax plan.
# FactCheck Articles: []
# News Articles: []
# CLAIM: Sandra Williams: "99.97 percent of the kids live in poverty that attend Cleveland public schools."
# FactCheck Articles: []
# News Articles: []
# CLAIM: State Tea Party Express: "In Wisconsin, Gov. Scott Walker has created a manufacturing-led jobs recovery. 30,000 new jobs were created this year, with 15,000 created in the struggling manufacturing sector."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Lisa Tomasso: "Rhode Island’s exports have increased by 53 percent in the last two years."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Donald Trump: "We’re making (Medicare) stronger. We’re making Social Security stronger."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Viral image: The man pictured in a mugshot is not Derek Chauvin, the officer who was recorded kneeling on George Floyd’s neck.
# FactCheck Articles: []
# News Articles: []
# CLAIM: Mark Perry: "Wisconsin is currently seeing an influx of new residents, Illinois is seeing an outflux."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Presente.org: "91 percent of Latinos support the DREAM Act, which allows undocumented youth to attend college," but Marco Rubio opposes it.
# FactCheck Articles: []
# News Articles: []
# CLAIM: Alan Grayson: "This is the year Florida becomes a majority minority state."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Adam Schiff: "We have not spoken directly with the whistleblower."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Reince Priebus: "We have unemployment that rivals the Great Depression."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Crossroads GPS: Says oil "production's down where Obama's in charge."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Claudia Tenney: Kim Myers "voted repeatedly to raise taxes on the people of Broome County, but made millions off of tax savings when her family business relocated its headquarters."
# FactCheck Articles: []
# News Articles: []
# CLAIM: James Quintero: Says that when San Francisco banned plastic grocery bags, "you saw the number of instances of people going to the ER with things like salmonella and other related illnesses" spike.
# FactCheck Articles: []
# News Articles: []
# CLAIM: Bloggers: Malia Obama was "among 10 arrested in racist Antifa attack," and the cop who arrested her was "found dead under suspicious circumstances."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Republican Party of Florida: Says Alex Sink supported "a $5.2 billion increase in Florida's debt."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Viral image: Says a photo shows Joe Biden groping a woman.
# FactCheck Articles: []
# News Articles: []
# CLAIM: LaKeshia Myers: "Wisconsin is one of only nine states in the nation in which 17 year-olds are automatically treated as adults in the criminal justice system."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Republican Party of Wisconsin: Says Mahlon Mitchell "received a massive raise on the backs of hard-working firefighters and turned the union into his own personal political slush fund."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Celia Israel: "When adjusted for inflation, (Texas) per-student spending has remained relatively flat over the past 16 years. Despite that trend, Texas schools in 2017 will receive $381 less per student than they did in 2003."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Bob Corker: A typical married couple "will contribute $119,000" into Medicare but will "receive $357,000 in Medicare benefits over their lifetimes."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Scott Walker: "The University of Wisconsin System budget is the biggest it has ever been."
# FactCheck Articles: []
# News Articles: []
# CLAIM: National Rifle Association: Wisconsin’s concealed-carry permit rules demand more proof than other states that safety training requirements are met, rendering "all existing (training) certificates insufficient" as part of the permit application
# FactCheck Articles: []
# News Articles: []
# CLAIM: Viral image: Early morning election results from Michigan and Wisconsin show voter fraud.
# FactCheck Articles: []
# News Articles: []
# CLAIM: Democratic Party of Virginia: "The proposed (Virginia) House budget cuts hundreds of millions in funding for public education…"
# FactCheck Articles: []
# News Articles: []
# CLAIM: Andrew Yang: "America’s life expectancy has declined for the last three years in a row, the first time in a hundred years, because of surges in suicides and drug overdoses."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Judicial Watch: "More than 100,000 DACA applicants have been arrested—Murder, Rape, DUI."
# FactCheck Articles: []
# News Articles: []
# CLAIM: John Boehner: "PWNED: House GOP Dominates Twitter, YouTube, Social Media in Congress."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Jennifer Carroll Foy: "Two out of our last three governors in Virginia were investigated by the FBI. One went to jail and one is running for office again in this election."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Chain email: Says Russian President Vladimir Putin got a standing ovation from the Duma after he gave a speech saying Muslims are "taking over" other countries but won't take over Russia.
# FactCheck Articles: []
# News Articles: []
# CLAIM: Jeb Bush: "Barack Obama will somehow manage to add more than $8 trillion to the national debt, which is more debt than the 43 presidents who held office before him compiled together."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Donald Trump: Says President Obama's "grandmother in Kenya said he was born in Kenya and she was there and witnessed the birth."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Bloggers: The COVID-19 vaccines "suppress the immune system" and make people more susceptible to HIV, shingles and herpes.
# FactCheck Articles: []
# News Articles: []
# CLAIM: Paul Krugman: Says "there have been some job gains in the McMansion State since Mr. Christie took office, but they have lagged gains both in the nation as a whole and in New York and Connecticut, the obvious points of comparison."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Donald Trump: "The FBI said (former national security adviser Michael Flynn) wasn't lying."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Barack Obama: Says Romney would add "trillions" to the deficit while Obama would "cut the deficit by $4 trillion."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Edwin Pacheco: Says Christopher Little has "a history of working against environmental protection by defending the worst types of corporate polluters"
# FactCheck Articles: []
# News Articles: []
# CLAIM: Donald Trump: President Barack Obama "wants to take in 250,000 (people) from Syria."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Facebook posts: Says Gov. Tony Evers "removed the American flag from the Capitol building"
# FactCheck Articles: []
# News Articles: []
# CLAIM: Brandon Morse: Says a video proves Pelosi "was planning" to rip up President Donald Trump’s State of the Union address "from the start."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Viral image: Unvaccinated people "are making the vaccinated people sick and die, but the unvaccinated people are not dead or sick."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Facebook posts: "Rand Paul’s medical license was just revoked!"
# FactCheck Articles: []
# News Articles: []
# CLAIM: Leah Vukmir: Says "I have been through the gauntlet, when we had riots in that Capitol."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Louie Gohmert: Says a Justice Department memo "directs that you must openly embrace gay marriage and homosexuality."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Facebook posts: Colorado "requires photo ID to vote in person, requires signature verification for mail-in ballots, which Georgia got rid of, and prevents campaign workers from giving food, water to voters within 100 feet if they’re wearing campaign apparel."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Charlie Crist: If Florida had not taken the stimulus, it "would have led to the firing of 20,000 teachers."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Bill O'Reilly: Says Supreme Court nominee Merrick Garland "voted, so the folks know, in Washington, D.C., to keep guns away from private citizens."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Brian Treece: Columbia, Mo., is "one of the fastest growing cities in the region, the only city in the state to grow jobs faster than the nation as a whole."
# FactCheck Articles: []
# News Articles: []
# CLAIM: AsAmericanAsApplePie.org: "San Juan city council votes unanimously to impeach Trump-hating mayor."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Justin Nelson: Says "our indicted Attorney General Ken Paxton is back to being the only statewide official in the country under indictment."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Crossroads GPS: "Unions don’t have to comply with Obamacare."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Arianna Huffington: Says although the unemployment rate seems to be improving, it does not reflect real job creation -- it’s caused by a "shrinking of the actual labor force."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Travis Allen: "Homelessness has skyrocketed across California. We have the nation’s highest homelessness rate and the nation’s highest homeless population."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Jim Steineke: The streetcar project planned by Mayor Tom Barrett would be a "1900s style trolley."
# FactCheck Articles: []
# News Articles: []
# CLAIM: David Pepper: "Many states without collective bargaining, such as Arizona, Nevada and North Carolina, have far larger budget deficits than many that do, including Ohio."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Marco Rubio: After Hurricane Hermine in 2016, Tallahassee "didn’t have power for weeks because (Mayor Andrew Gillum) stood in the way of crews being able to come in and restore power, because they weren’t members of the right union or something."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Tweets: "Books banned in Texas include 1984, Maus, and The Handmaid's Tale, but not Mein Kampf."
# FactCheck Articles: []
# News Articles: []
# CLAIM: John Boccieri: "Mr. Renacci was registered as a foreign trade lobbyist in the United States government."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Democratic Party of Wisconsin: Says Donald Trump used farmers’ struggles "to push through a multi-billion dollar bailout program that was nothing more than a handout for large agricultural companies."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Corey Lewandowski: "The chairman of the party of Florida, who is an avid and outward supporter of Marco Rubio, gets to appoint 30 of those delegates."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Bruce Rauner: Says "massive floods" led to Legionnaires’ disease outbreaks at the Quincy Veterans’ Home.
# FactCheck Articles: []
# News Articles: []
# CLAIM: Bernie Sanders: "When you're white ... you don't know what it's like to be poor."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Maria Shriver: "Two-thirds of American families rely on the mother's income to stay above the poverty level."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Facebook posts: "Trump is in White House! He promises to lock up Hillary!"
# FactCheck Articles: []
# News Articles: []
# CLAIM: Roberto DaSilva: "Ten percent of violent deaths in the U.S. each year are due to strangulation."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Joni Ernst: The Obama administration issued an "11th-hour rule that entrenches federal family planning funding for Planned Parenthood."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Facebook posts: Says Nancy Pelosi said, "Waiting long hours in the emergency room will allow you to make new friends!"
# FactCheck Articles: []
# News Articles: []
# CLAIM: Pete Buttigieg: Says President Donald Trump has been "taking money Congress authorized to protect people facing disaster in order to indefinitely detain asylum seekers."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Facebook posts: Says Marco Rubio said that "felons should not have their voting rights restored" but that "convicted felons should be allowed to own guns after they have done their time."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Josh Hawley: Says activists threatened his family and "screamed threats, vandalized, and tried to pound open our door."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Facebook posts: Photos show "Ukrainian Christians pray outdoors, in the snow, for their country in this phase of war danger."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Bill O'Reilly: Tells President Barack Obama that he also asked former President George W. Bush about how he felt about Americans hating him.
# FactCheck Articles: []
# News Articles: []
# CLAIM: Karl Rove: Under a public health care option, 120 million Americans will "lose what they now get from private companies and be forced onto the government-run rolls as businesses decide it is more cost-effective for them to drop coverage."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Facebook posts: Says a video shows Iranian rockets being launched toward a U.S. air base in Iraq.
# FactCheck Articles: []
# News Articles: []
# CLAIM: Michelle Nunn: Says by rejecting an expansion of Medicaid under the new law, Georgia was depriving 25,000 veterans of health care coverage.
# FactCheck Articles: []
# News Articles: []
# CLAIM: Duriya Farooqui: "Of the 18 stadiums built from 2004 to 2013, 47 percent of the total cost came from public sources."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Marco Rubio: "In about three weeks over a half million Floridians are going to lose their coverage again" through Obamacare.
# FactCheck Articles: []
# News Articles: []
# CLAIM: City of Austin: "Nearly 20% of our residents" are born abroad.
# FactCheck Articles: []
# News Articles: []
# CLAIM: Hillary Clinton: "We are seeing kids who are healthier."
# FactCheck Articles: []
# News Articles: []
# CLAIM: West Virginia Democratic Party: The Affordable Care Act "provided over 200,000 West Virginians with health care coverage."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Viral image: "2,000 illegal aliens were arrested by ICE in 2017 for murders committed here in the United States!"
# FactCheck Articles: []
# News Articles: []
# CLAIM: Tom Daschle: U.S. global AIDS spending helped reduce "political instability and violence" by "40 percent" in recipient nations.
# FactCheck Articles: []
# News Articles: []
# CLAIM: Club for Growth: Audio clips from ad show Pat McCrory supported Black Lives Matter protesters while condemning ‘Trump supporters’
# FactCheck Articles: []
# News Articles: []
# CLAIM: Lon Burnam: "Russia has more diversity in its governmental representation than we do in Texas."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Rodney Davis: House Speaker Nancy Pelosi’s "office was calling the shots on all of their (Capitol security officials’) actions on Jan. 6."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Sharlene Leurig: "Austin is the only city in an arid landscape in the western United States dependent on a single source of water."
# FactCheck Articles: []
# News Articles: []
# CLAIM: John McCain: "Obama himself voted against funding our nation's veterans and troops in the field during a time of war."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Steven Goldstein: "Polls now show a majority of Catholics favor marriage equality."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Chain email: "The President wants the U.S. to sign on to the U.N.’s International Criminal Court."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Facebook posts: Says Donald Trump wrote in his book, "Being an atheist gives me an edge in every deal. Christians are too moral for business."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Donald Trump: "In the first full month of my administration following the issuance of my executive orders, illegal immigration on our southern border fell by an unprecedented 40 percent."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Charlie Crist: Says property insurance rates are going up because Rick Scott signed a bill preventing the state from regulating insurance.
# FactCheck Articles: []
# News Articles: []
# CLAIM: Donald Trump: "Our new (health care) plans are up to 60% less expensive and better" than Obamacare.
# FactCheck Articles: []
# News Articles: []
# CLAIM: John McCain: Earmarks requested in a federal spending bill included  "$277,000 for potato pest management in Wisconsin."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Ted Wheeler: Says the treasurer’s office has "saved $37 million in management costs for the oversight of public investments."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Bloggers: "NBC just fired Megyn Kelly before her new show begins."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Conservative Tribune: "Before Leaving, Obama Enacts Rules to Take $3,000 From EVERY American."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Charlie Crist: Marco Rubio "wants to raise the Social Security retirement age," and "cut benefits."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Donald Trump: Speaking of his restriction on travel from China, "I had (Joe) Biden calling me xenophobic. … He called me a racist, because of the fact that he felt it was a racist thing to stop people from China coming in."
# FactCheck Articles: []
# News Articles: []
# CLAIM: American Postal Workers Union: "The U.S. Postal Service doesn’t run on your tax dollars. It’s funded solely by stamps and postage."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Tim Scott: "If you don't pay income taxes ... you'll have more money" under the Republican tax plan.
# FactCheck Articles: []
# News Articles: []
# CLAIM: Sandra Williams: "99.97 percent of the kids live in poverty that attend Cleveland public schools."
# FactCheck Articles: []
# News Articles: []
# CLAIM: State Tea Party Express: "In Wisconsin, Gov. Scott Walker has created a manufacturing-led jobs recovery. 30,000 new jobs were created this year, with 15,000 created in the struggling manufacturing sector."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Lisa Tomasso: "Rhode Island’s exports have increased by 53 percent in the last two years."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Donald Trump: "We’re making (Medicare) stronger. We’re making Social Security stronger."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Viral image: The man pictured in a mugshot is not Derek Chauvin, the officer who was recorded kneeling on George Floyd’s neck.
# FactCheck Articles: []
# News Articles: []
# CLAIM: Mark Perry: "Wisconsin is currently seeing an influx of new residents, Illinois is seeing an outflux."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Presente.org: "91 percent of Latinos support the DREAM Act, which allows undocumented youth to attend college," but Marco Rubio opposes it.
# FactCheck Articles: []
# News Articles: []
# CLAIM: Alan Grayson: "This is the year Florida becomes a majority minority state."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Adam Schiff: "We have not spoken directly with the whistleblower."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Reince Priebus: "We have unemployment that rivals the Great Depression."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Crossroads GPS: Says oil "production's down where Obama's in charge."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Claudia Tenney: Kim Myers "voted repeatedly to raise taxes on the people of Broome County, but made millions off of tax savings when her family business relocated its headquarters."
# FactCheck Articles: []
# News Articles: []
# CLAIM: James Quintero: Says that when San Francisco banned plastic grocery bags, "you saw the number of instances of people going to the ER with things like salmonella and other related illnesses" spike.
# FactCheck Articles: []
# News Articles: []
# CLAIM: Bloggers: Malia Obama was "among 10 arrested in racist Antifa attack," and the cop who arrested her was "found dead under suspicious circumstances."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Republican Party of Florida: Says Alex Sink supported "a $5.2 billion increase in Florida's debt."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Viral image: Says a photo shows Joe Biden groping a woman.
# FactCheck Articles: []
# News Articles: []
# CLAIM: LaKeshia Myers: "Wisconsin is one of only nine states in the nation in which 17 year-olds are automatically treated as adults in the criminal justice system."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Republican Party of Wisconsin: Says Mahlon Mitchell "received a massive raise on the backs of hard-working firefighters and turned the union into his own personal political slush fund."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Celia Israel: "When adjusted for inflation, (Texas) per-student spending has remained relatively flat over the past 16 years. Despite that trend, Texas schools in 2017 will receive $381 less per student than they did in 2003."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Bob Corker: A typical married couple "will contribute $119,000" into Medicare but will "receive $357,000 in Medicare benefits over their lifetimes."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Scott Walker: "The University of Wisconsin System budget is the biggest it has ever been."
# FactCheck Articles: []
# News Articles: []
# CLAIM: National Rifle Association: Wisconsin’s concealed-carry permit rules demand more proof than other states that safety training requirements are met, rendering "all existing (training) certificates insufficient" as part of the permit application
# FactCheck Articles: []
# News Articles: []
# CLAIM: Viral image: Early morning election results from Michigan and Wisconsin show voter fraud.
# FactCheck Articles: []
# News Articles: []
# CLAIM: Democratic Party of Virginia: "The proposed (Virginia) House budget cuts hundreds of millions in funding for public education…"
# FactCheck Articles: []
# News Articles: []
# CLAIM: Andrew Yang: "America’s life expectancy has declined for the last three years in a row, the first time in a hundred years, because of surges in suicides and drug overdoses."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Judicial Watch: "More than 100,000 DACA applicants have been arrested—Murder, Rape, DUI."
# FactCheck Articles: []
# News Articles: []
# CLAIM: John Boehner: "PWNED: House GOP Dominates Twitter, YouTube, Social Media in Congress."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Jennifer Carroll Foy: "Two out of our last three governors in Virginia were investigated by the FBI. One went to jail and one is running for office again in this election."
# FactCheck Articles: []
# News Articles: []
# CLAIM: Chain email: Says Russian President Vladimir Putin got a standing ovation from the Duma after he gave a speech saying Muslims are "taking over" other countries but won't take over Russia.
# FactCheck Articles: []
# News Articles: []
# 12 minutes and 14.23 seconds

# %%
import matplotlib.pyplot as plt
import numpy as np

# Benchmark data
models =  [item["name"] for item in modelResults]
acc = [item["acc"] for item in modelResults]
f1 = [item["f1"] for item in modelResults]

# Bar chart parameters
x = np.arange(len(models))  # Position of bars
width = 0.4  # Width of bars

# Create the plot
fig, ax = plt.subplots()
bars = ax.bar(x, acc, width, color=['blue', 'green', 'purple', 'orange'])

# Add labels, title, and custom ticks
ax.set_xlabel('Models')
ax.set_ylabel('Acc. Scores')
ax.set_title('Comparison of Benchmark Accuracy')
ax.set_xticks(x)
ax.set_xticklabels(models)
ax.set_ylim(0, 1)  # Adjust y-axis range if needed
ax.bar_label(bars, fmt='%.2f', padding=3)  # Add values on top of bars

# Show the chart
plt.tight_layout()
plt.show()

# %%
# Bar chart parameters
x = np.arange(len(models))  # Position of bars
width = 0.4  # Width of bars

# Create the plot
fig, ax = plt.subplots()
bars = ax.bar(x, f1, width, color=['blue', 'green', 'purple', 'orange'])

# Add labels, title, and custom ticks
ax.set_xlabel('Models')
ax.set_ylabel('F1 Scores')
ax.set_title('Comparison of Benchmark F1')
ax.set_xticks(x)
ax.set_xticklabels(models)
ax.set_ylim(0, 1)  # Adjust y-axis range if needed
ax.bar_label(bars, fmt='%.2f', padding=3)  # Add values on top of bars

# Show the chart
plt.tight_layout()
plt.show()

# %%
import pickle

feverResults = (dfPol['statement'].values, modelResults)

# Save to Pickle file
with open("benchmarking/politifact/results2.pkl", "wb") as f:
    pickle.dump(feverResults, f)

# # Load from Pickle file
# with open("benchmarking/politifact/results.pkl", "rb") as f:
#     loaded_data = pickle.load(f)
