# %% [markdown]
# # Benchmarking FEVER Suite

# %%
from langchain_community.llms import Ollama
from factCheck import factCheckSingleClaim, factCheckSingleClaimNoContext

OLLAMA_HOST = "http://host.docker.internal:11434" # for when running within docker image
# OLLAMA_HOST = "http://localhost:11434"
 
ollama3 = Ollama(model="llama3", base_url=OLLAMA_HOST)
ollama32 = Ollama(model="llama3.2", base_url=OLLAMA_HOST)

claimCount = 100
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
from sklearn.metrics import accuracy_score, f1_score

# Evaluation function
def evaluate_model(predictions, y):
    for idx in range(len(predictions)):
        if y[idx] in predictions[idx]:
            predictions[idx] = y[idx];
        else:
            predictions[idx] = predictions[idx][0];
    
    # Ensure predictions and dataset labels are aligned
    accuracy = accuracy_score(y, predictions)
    f1 = f1_score(y, predictions, average='weighted')
    return accuracy, f1

# %%
from benchmarking.FEVER.feverEval import get_fever_sample

dfFever = get_fever_sample(claimCount, './benchmarking/FEVER/train.jsonl', 42)

# %%
import time
from datetime import datetime
start_time = time.time()

feverMapping = {
    "true": ["SUPPORTS"],
    "mostly true": ["SUPPORTS"],
    "mostly false": ["REFUTES"],
    "false": ["REFUTES"],
    "not enough evidence": ["NOT ENOUGH INFO"]
}

modelResults = [{'name': 'FactCheck3'}, {'name': 'FactCheck32'}, {'name': 'Llama3'}, {'name': 'Llama32'}]
for modelIndex, model in enumerate([ollama3, ollama32]):
    # FactCheckLLM check
    origPred = []
    feverPred = []
    responses = []
    for row in dfFever.iterrows(): 
        pred = await factCheckSingleClaim(row[1]['claim'], model)
        origPred.append(pred['label'].lower())
        pred['label'] = feverMapping[pred['label'].lower()]
        feverPred.append(pred['label'])
        responses.append(pred['reply'])
        
    modelResults[modelIndex]['dataset'] = 'FEVER';
    modelResults[modelIndex]['original-prediction'] = origPred;
    modelResults[modelIndex]['mapped-predictions'] = feverPred;
    modelResults[modelIndex]['res'] = responses;
    
    acc, f1 = evaluate_model(feverPred, dfFever['label'].values)
    modelResults[modelIndex]['acc'] = acc
    modelResults[modelIndex]['f1'] = f1
    
    # base model check
    origPred = []
    feverPred = []
    responses = []
    for row in dfFever.iterrows(): 
        pred = await factCheckSingleClaimNoContext(row[1]['claim'], model)
        origPred.append(pred['label'].lower())
        pred['label'] = feverMapping[pred['label'].lower()]
        feverPred.append(pred['label'])
        responses.append(pred['reply'])
        
    modelResults[modelIndex+2]['dataset'] = 'FEVER';
    modelResults[modelIndex+2]['original-prediction'] = origPred;
    modelResults[modelIndex+2]['mapped-predictions'] = feverPred;
    modelResults[modelIndex]['res'] = responses;
    
    acc, f1 = evaluate_model(feverPred, dfFever['label'].values)
    modelResults[modelIndex+2]['acc'] = acc
    modelResults[modelIndex+2]['f1'] = f1

end_time = time.time()
elapsed_time = end_time - start_time
minutes, seconds = divmod(elapsed_time, 60)
print(f"{int(minutes)} minutes and {seconds:.2f} seconds")
# Out:
# CLAIM: Cricket is followed in Cuba.
# FactCheck Articles: []
# News Articles: [{'title': 'Vodka Casino Live Casino  Free spins for beginners  Big games catalog', 'url': 'https://www.pausaparafeminices.com/news/vodka-casino-live-casino-free-spins-for-beginners-23/'}, {'title': 'Notes on Guyana', 'url': 'https://mattlakeman.org/2024/11/08/notes-on-guyana/'}]
# Snopes Articles: [{'title': 'Vodka Casino Live Casino  Free spins for beginners  Big games catalog', 'url': 'https://www.pausaparafeminices.com/news/vodka-casino-live-casino-free-spins-for-beginners-23/'}, {'title': 'Notes on Guyana', 'url': 'https://mattlakeman.org/2024/11/08/notes-on-guyana/'}]
# Politifact Articles: [{'title': 'Vodka Casino Live Casino  Free spins for beginners  Big games catalog', 'url': 'https://www.pausaparafeminices.com/news/vodka-casino-live-casino-free-spins-for-beginners-23/'}, {'title': 'Notes on Guyana', 'url': 'https://mattlakeman.org/2024/11/08/notes-on-guyana/'}, {'title': '"Virginia now is the number one exporter of (agricultural) products to Cuba. We have now jumped to number one."', 'url': 'https://www.politifact.com/factchecks/2016/mar/24/terry-mcauliffe/mcauliffe-right-va-sends-most-agricultural-product/'}, {'title': 'Says his parents "came to America following Fidel Castro\'s takeover" of Cuba.', 'url': 'https://www.politifact.com/factchecks/2011/oct/21/marco-rubio/sen-marco-rubio-said-his-parents-came-america-foll/'}]
# CLAIM: Quebec has a region inhabited primarily by Canadian Aboriginal peoples.
# FactCheck Articles: []
# News Articles: []
# Snopes Articles: []
# Politifact Articles: [{'title': 'Arson, not climate change, caused Canada’s record 2023 wildfire season.', 'url': 'https://www.politifact.com/factchecks/2024/feb/12/instagram-posts/small-number-of-arsons-dont-negate-climate-changes/'}, {'title': 'Video shows that Royal Canadian Mounted Police investigators determined that “dozens of wildfires in Canada” were caused by arson in 2023.', 'url': 'https://www.politifact.com/factchecks/2023/jul/20/facebook-posts/claims-connecting-arsonists-to-dozens-of-recent-wi/'}]
# CLAIM: The Eagles's lead guitarist was Carlos Santana for 27 years.
# Cache miss. Fetching data from website.
# FactCheck Articles: []
# Cache miss. Fetching data from API.
# Rate limit reached for API key: 4ac92a95346643fdbdb26a7e4d0e98b1. Trying next key.
# News Articles: []
# Cache miss. Fetching data from website.
# Found 1 articles
# Snopes Articles: []
# Cache miss. Fetching data from website.
# Found 40 articles
# Politifact Articles: [{'title': '"JUST IN: The Vatican has invited Chelsea Clinton, Dr. Fauci, New Age figure Deepak Chopra and the CEOs of Moderna and Pfizer to speak at a May conference focusing on \'health\' and the \'soul.\'"', 'url': 'https://www.politifact.com/factchecks/2022/mar/29/facebook-posts/vatican-conference-was-held-2021-not-upcoming/'}, {'title': 'Says former Miami-Dade Mayor Carlos Alvarez and current mayoral candidate Carlos Gimenez\xa0 both drove fancy European cars at taxpayer expense.', 'url': 'https://www.politifact.com/factchecks/2011/jun/20/accountability-project/miami-mayors-race-third-party-group-tries-tie-carl/'}]
# CLAIM: James Bond was reviewed by Ian Fleming.
# Cache miss. Fetching data from website.
# FactCheck Articles: []
# Cache miss. Fetching data from API.
# Rate limit reached for API key: 4ac92a95346643fdbdb26a7e4d0e98b1. Trying next key.
# News Articles: []
# Cache miss. Fetching data from website.
# Found 1 articles
# Snopes Articles: []
# Cache miss. Fetching data from website.
# Found 40 articles
# Politifact Articles: [{'title': '"The head of the IRS ordered 24,000 emails erased before Congress could review them, making sure the American people will never know the real truth."', 'url': 'https://www.politifact.com/factchecks/2016/sep/15/john-fleming/john-fleming-attacks-irs-inaccurate-radio-ad/'}, {'title': 'In Massachusetts, "half of the primary care doctors are not accepting new patients."', 'url': 'https://www.politifact.com/factchecks/2013/oct/29/john-fleming/gop-rep-john-fleming-says-massachusetts-half-prima/'}]
# CLAIM: Prometheus is not a 2012 film that serves as a prequel.
# Cache miss. Fetching data from website.
# FactCheck Articles: []
# Cache miss. Fetching data from API.
# Rate limit reached for API key: 4ac92a95346643fdbdb26a7e4d0e98b1. Trying next key.
# News Articles: [{'title

# Cache miss. Fetching data from website.
# FactCheck Articles: []
# Cache miss. Fetching data from API.
# Rate limit reached for API key: 4ac92a95346643fdbdb26a7e4d0e98b1. Trying next key.
# News Articles: []
# Cache miss. Fetching data from website.
# Found 1 articles
# Snopes Articles: []
# Cache miss. Fetching data from website.
# Found 40 articles
# Politifact Articles: [{'title': 'Says some Georgians can get health insurance for $105 a month. \xa0', 'url': 'https://www.politifact.com/factchecks/2014/mar/25/kathleen-sebelius/low-cost-insurance-available-subsidies/'}, {'title': 'Congress includes 36 people accused of spousal abuse, 84 arrested for drunk driving in the past year, 71 with terrible credit\xa0and more.', 'url': 'https://www.politifact.com/factchecks/2014/sep/24/facebook-posts/nba-nfl-congress-spousal-abuse-fraud-bad-checks-ba/'}]
# CLAIM: Hitler was appointed Chancellor of Germany on 30 January 1933.
# Cache miss. Fetching data from website.
# FactCheck Articles: []
# Cache miss. Fetching data from API.
# Rate limit reached for API key: 4ac92a95346643fdbdb26a7e4d0e98b1. Trying next key.
# News Articles: []
# Cache miss. Fetching data from website.
# Found 1 articles
# Snopes Articles: []
# Cache miss. Fetching data from website.
# Found 40 articles
# Politifact Articles: [{'title': 'Nazi Germany’s Hermann Göring worked to "defund and eliminate the police departments so that they would not interfere with his Brown Shirts."', 'url': 'https://www.politifact.com/factchecks/2020/jun/18/instagram-posts/social-posts-comparing-defund-police-nazi-germany-/'}, {'title': 'Quotes Adolf Hitler as saying the best way to control a people is "to take a little of their freedom at a time."', 'url': 'https://www.politifact.com/factchecks/2019/apr/01/facebook-posts/did-hitler-say-best-way-control-people-take-little/'}]
# CLAIM: Daddy Yankee is from Haiti.
# Cache miss. Fetching data from website.
# FactCheck Articles: []
# Cache miss. Fetching data from API.
# Rate limit reached for API key: 4ac92a95346643fdbdb26a7e4d0e98b1. Trying next key.
# News Articles: []
# Cache miss. Fetching data from website.
# Error calling snopes, skipping: Page.goto: Timeout 30000ms exceeded.
# Call log:
# navigating to "https://www.snopes.com/search/?#gsc.tab=0&gsc.page=1&gsc.q=Daddy%20Yankee%20is%20from%20Haiti.", waiting until "load"
#
# Snopes Articles: []
# Cache miss. Fetching data from website.
# Found 40 articles
# Politifact Articles: [{'title': '"Rooting for the Red Sox is like rooting for the drug companies."', 'url': 'https://www.politifact.com/factchecks/2011/aug/29/sherrod-brown/sen-sherrod-brown-likens-rooting-red-sox-rooting-d/'}, {'title': '"I remember one of [Curt Schilling\'s] teammates said he painted his sock, the bloody sock."', 'url': 'https://www.politifact.com/factchecks/2010/jul/27/lincoln-chafee/chafee-says-schilling-faked-bloody-sock/'}]
# CLAIM: The world's fifth largest exporter is South Korea.
# Cache miss. Fetching data from website.
# FactCheck Articles: []
# Cache miss. Fetching data from API.
# Rate limit reached for API key: 4ac92a95346643fdbdb26a7e4d0e98b1. Trying next key.
# News Articles: [{'title': '[Removed]', 'url': 'https://removed.com'}, {'title': 'In South Korea, nations meet in final round to address global plastic crisis', 'url': 'https://abcnews.go.com/International/wireStory/south-korea-nations-meet-final-round-address-global-116187940'}]
# Cache miss. Fetching data from website.
# Error calling snopes, skipping: Page.goto: Timeout 30000ms exceeded.
# Call log:
# navigating to "https://www.snopes.com/search/?#gsc.tab=0&gsc.page=1&gsc.q=The%20world%27s%20fifth%20largest%20exporter%20is%20South%20Korea.", waiting until "load"
#
# Snopes Articles: [{'title': '[Removed]', 'url': 'https://removed.com'}, {'title': 'In South Korea, nations meet in final round to address global plastic crisis', 'url': 'https://abcnews.go.com/International/wireStory/south-korea-nations-meet-final-round-address-global-116187940'}]
# Cache miss. Fetching data from website.
# Found 40 articles
# Politifact Articles: [{'title': '[Removed]', 'url': 'https://removed.com'}, {'title': 'In South Korea, nations meet in final round to address global plastic crisis', 'url': 'https://abcnews.go.com/International/wireStory/south-korea-nations-meet-final-round-address-global-116187940'}, {'title': '"We rank below Ethiopia, I\'m told, in terms of our exports per capita, well below any of the other developed countries we trade with, and well below China and (South) Korea."', 'url': 'https://www.politifact.com/factchecks/2011/aug/25/rob-portman/sen-rob-portman-says-us-export-values-capita-lag-e/'}, {'title': '"Last year, Korea sold nearly half a million cars in our country. ... The United States, you know how much we sell to them? Six thousand. What kind of deal is that?"', 'url': 'https://www.politifact.com/factchecks/2011/oct/04/marcy-kaptur/marcy-kaptur-says-us-imported-500000-cars-south-ko/'}]
# CLAIM: The Boys from Brazil stars actors.
# Cache miss. Fetching data from website.
# FactCheck Articles: []
# Cache miss. Fetching data from API.
# Rate limit reached for API key: 4ac92a95346643fdbdb26a7e4d0e98b1. Trying next key.
# News Articles: [{'title

# Cache miss. Fetching data from website.
# FactCheck Articles: []
# Cache miss. Fetching data from API.
# Rate limit reached for API key: 4ac92a95346643fdbdb26a7e4d0e98b1. Trying next key.
# News Articles: [{'title': 'What Movie Should I Watch Tonight? ‘Poolman’ on Hulu', 'url': 'https://decider.com/2024/11/23/what-movie-should-i-watch-tonight-poolman-on-hulu/'}]
# Cache miss. Fetching data from website.
# Error calling snopes, skipping: Page.goto: Timeout 30000ms exceeded.
# Call log:
# navigating to "https://www.snopes.com/search/?#gsc.tab=0&gsc.page=1&gsc.q=Danny%20DeVito%20produced%20Erin%20Brockovich.", waiting until "load"
#
# Snopes Articles: [{'title': 'What Movie Should I Watch Tonight? ‘Poolman’ on Hulu', 'url': 'https://decider.com/2024/11/23/what-movie-should-i-watch-tonight-poolman-on-hulu/'}]
# Cache miss. Fetching data from website.
# Found 40 articles
# Politifact Articles: [{'title': 'What Movie Should I Watch Tonight? ‘Poolman’ on Hulu', 'url': 'https://decider.com/2024/11/23/what-movie-should-i-watch-tonight-poolman-on-hulu/'}, {'title': 'Says Donald Trump tweeted, "Danny DeVito supports baby murder."', 'url': 'https://www.politifact.com/factchecks/2019/dec/09/viral-image/no-donald-trump-didnt-say-danny-devito-supports-ba/'}, {'title': '"Trump has selected his pick for running mate (and the) news stuns Republican Party.”', 'url': 'https://www.politifact.com/factchecks/2023/nov/28/facebook-posts/donald-trump-has-not-announced-his-2024-vice-presi/'}]
# CLAIM: The 2011 FIFA U-20 World Cup had matches in eight Colombian cities.
# Cache miss. Fetching data from website.
# FactCheck Articles: []
# Cache miss. Fetching data from API.
# Rate limit reached for API key: 4ac92a95346643fdbdb26a7e4d0e98b1. Trying next key.
# News Articles: []
# Cache miss. Fetching data from website.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Benchmark data
models =  [item["name"] for item in modelResults]
acc = [item["acc"] for item in modelResults]
f1 = [item["f1"] for item in modelResults]

# Bar chart parameters
x = np.arange(len(models))  # Position of bars
width = 0.4  # Width of bars

# Create the plot
fig, ax = plt.subplots()
bars = ax.bar(x, acc, width, color=['blue', 'green', 'purple', 'orange'])

# Add labels, title, and custom ticks
ax.set_xlabel('Models')
ax.set_ylabel('Acc. Scores')
ax.set_title('Comparison of Benchmark Accuracy')
ax.set_xticks(x)
ax.set_xticklabels(models)
ax.set_ylim(0, 1)  # Adjust y-axis range if needed
ax.bar_label(bars, fmt='%.2f', padding=3)  # Add values on top of bars

# Show the chart
plt.tight_layout()
plt.show()

# %%
# Bar chart parameters
x = np.arange(len(models))  # Position of bars
width = 0.4  # Width of bars

# Create the plot
fig, ax = plt.subplots()
bars = ax.bar(x, f1, width, color=['blue', 'green', 'purple', 'orange'])

# Add labels, title, and custom ticks
ax.set_xlabel('Models')
ax.set_ylabel('F1 Scores')
ax.set_title('Comparison of Benchmark F1')
ax.set_xticks(x)
ax.set_xticklabels(models)
ax.set_ylim(0, 1)  # Adjust y-axis range if needed
ax.bar_label(bars, fmt='%.2f', padding=3)  # Add values on top of bars

# Show the chart
plt.tight_layout()
plt.show()

# %%
import pickle

feverResults = (dfFever['claim'].values, modelResults)

# Save to Pickle file
with open("benchmarking/FEVER/results4.pkl", "wb") as f:
    pickle.dump(feverResults, f)

# # Load from Pickle file
# with open("benchmarking/AVERITEC/results.pkl", "rb") as f:
#     loaded_data = pickle.load(f)
